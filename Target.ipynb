# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# def tracer_cible(rayon, size):
#     theta = np.linspace(0, 2*np.pi, 100)
#     x1 = rayon*np.cos(theta)
#     x2 = rayon*np.sin(theta)
#     ax.plot(x1,x2, color = 'red')
#     ax.set_xlim(-size,size)
#     ax.set_ylim(-size,size)
#tracer_cible(rayon = 2)
def lancer(centre, rayon, size):
    '''
    Tracer cible
    '''
    fig, ax = plt.subplots(figsize = (20/2,15/2))
    theta = np.linspace(0, 2*np.pi, 100)
    x1 = rayon*np.cos(theta)
    x2 = rayon*np.sin(theta)
    ax.plot(x1,x2, color = 'red')
    ax.set_xlim(-size,size)
    ax.set_ylim(-size,size)
    
    '''
    Tracer flèche
    '''
    x = random.uniform(-size,size)
    y = random.uniform(-size,size)
    ax.scatter(x,y, c = 'blue', marker = 'x', s = 250)
    
#     while not (np.sqrt(x**2+y**2)<rayon):
#         jeu(centre, rayon, size)

    if np.sqrt(x**2+y**2)<rayon:
        return False
    return True

def jeu(centre, rayon, size):
    step = lancer(10, rayon, size)
    k = 1
    while step:
        step = lancer(10, rayon, size)
        k = k + 1
    return k

jeu(10, rayon = 9, size = 10)

# print(f"Réussi au bout de {k} essaies")
# Out:
# 2
